# %% [markdown]
# # Review Analysis

# %% [markdown]
# In this exercise, you will go back to the Olist dataset. Run the code below to load the data.

# %%
import pandas as pd

df = pd.read_csv("https://wagon-public-datasets.s3.amazonaws.com/Machine%20Learning%20Datasets/reviews.csv")

df.head()
# Out:
# /Users/shu/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (1,2) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                           review_id length_review review_score  \
# 0  7bc2406110b926393aa56f80a40eba40             0            4
# 1  80e641a11e56f04c1ad469d5645fdfde             0            5
# 2  228ce5500dc1d8e020d8d1322874b6f0             0            5
# 3  e64fb393e7b32834bb789ff8bb30750e            37            5
# 4  f7c4243c7fe1938f181bec41a392bdeb           100            5
#
#                            order_id   product_category_name  \
# 0  73fc7af87114b39712e6da79b0a377eb           esporte_lazer
# 1  a548910a1c6147796b98fdf73dbeba33  informatica_acessorios
# 2  f9e4b658b201a9f2ecdecbb34bed034b  informatica_acessorios
# 3  658677c97b385a9be170737859d3511b      ferramentas_jardim
# ...

# %% [markdown]
# 👇 Analyse the comment reviews to understand what causes the bad review scores.

# %%
df["review_comment_message"]
# Out:
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                    Recebi bem antes do prazo estipulado.
# 4        Parabéns lojas lannister adorei comprar pela I...
#                                ...
# 99427                                                  NaN
# 99428    Excelente mochila, entrega super rápida. Super...
# 99429                                                  NaN
# 99430    Solicitei a compra de uma capa de retrovisor c...
# 99431    meu produto chegou e ja tenho que devolver, po...
# Name: review_comment_message, Length: 99432, dtype: object

# %%
df
# Out:
#                               review_id length_review review_score  \
# 0      7bc2406110b926393aa56f80a40eba40             0            4
# 1      80e641a11e56f04c1ad469d5645fdfde             0            5
# 2      228ce5500dc1d8e020d8d1322874b6f0             0            5
# 3      e64fb393e7b32834bb789ff8bb30750e            37            5
# 4      f7c4243c7fe1938f181bec41a392bdeb           100            5
# ...                                 ...           ...          ...
# 99427  f3897127253a9592a73be9bdfdf4ed7a             0            5
# 99428  b3de70c89b1510c4cd3d0649fd302472            67            5
# 99429  1adeb9d84d72fe4e337617733eb85149             0            4
# 99430  be360f18f5df1e0541061c87021e6d93           198            1
# 99431  efe49f1d6f951dd88b51e6ccd4cc548f            85            1
#
#                                order_id   product_category_name  \
# 0      73fc7af87114b39712e6da79b0a377eb           esporte_lazer
# ...

# %%
string.punctuation
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/tg/p4s0x3b55936405b1y1vws6h0000gn/T/ipykernel_9615/1923921221.py in <module>
# ----> 1 string.punctuation
#
# NameError: name 'string' is not defined

# %%
import string

def punc_lower(data):
    data=str(data)
    for punctuation in string.punctuation:
        data=data.replace(punctuation," ")
    return data

df["clean_review_comment_message"]=df["review_comment_message"].apply(punc_lower)

# %%
df
# Out:
#                               review_id length_review review_score  \
# 0      7bc2406110b926393aa56f80a40eba40             0            4
# 1      80e641a11e56f04c1ad469d5645fdfde             0            5
# 2      228ce5500dc1d8e020d8d1322874b6f0             0            5
# 3      e64fb393e7b32834bb789ff8bb30750e            37            5
# 4      f7c4243c7fe1938f181bec41a392bdeb           100            5
# ...                                 ...           ...          ...
# 99427  f3897127253a9592a73be9bdfdf4ed7a             0            5
# 99428  b3de70c89b1510c4cd3d0649fd302472            67            5
# 99429  1adeb9d84d72fe4e337617733eb85149             0            4
# 99430  be360f18f5df1e0541061c87021e6d93           198            1
# 99431  efe49f1d6f951dd88b51e6ccd4cc548f            85            1
#
#                                order_id   product_category_name  \
# 0      73fc7af87114b39712e6da79b0a377eb           esporte_lazer
# ...

# %%
clean_review_comment_message
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/tg/p4s0x3b55936405b1y1vws6h0000gn/T/ipykernel_9615/1366502772.py in <module>
# ----> 1 clean_review_comment_message
#
# NameError: name 'clean_review_comment_message' is not defined

# %%
# from nltk.corpus import stopwords
# from nltk.tokenize import word_tokenize

# stop_words=set(stopwords.words("english"))
# word_tokens=word_tokenize()

# %%
df["clean_review_comment_message"]=df["clean_review_comment_message"].dropna(axis=0)

# %%
df
# Out:
#                               review_id length_review review_score  \
# 0      7bc2406110b926393aa56f80a40eba40             0            4
# 1      80e641a11e56f04c1ad469d5645fdfde             0            5
# 2      228ce5500dc1d8e020d8d1322874b6f0             0            5
# 3      e64fb393e7b32834bb789ff8bb30750e            37            5
# 4      f7c4243c7fe1938f181bec41a392bdeb           100            5
# ...                                 ...           ...          ...
# 99427  f3897127253a9592a73be9bdfdf4ed7a             0            5
# 99428  b3de70c89b1510c4cd3d0649fd302472            67            5
# 99429  1adeb9d84d72fe4e337617733eb85149             0            4
# 99430  be360f18f5df1e0541061c87021e6d93           198            1
# 99431  efe49f1d6f951dd88b51e6ccd4cc548f            85            1
#
#                                order_id   product_category_name  \
# 0      73fc7af87114b39712e6da79b0a377eb           esporte_lazer
# ...

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer

from sklearn.naive_bayes import MultinomialNB

pipeline=Pipeline([
    ("tfidf",TfidfVectorizer()),
    ("nb",MultinomialNB())
])

parameters = {
    'tfidf__ngram_range': ((1,1), (2,2)),
    'nb__alpha': (0.1,1),}


grid_search = GridSearchCV(pipeline, parameters, n_jobs=-1, 
                           verbose=1, scoring = "accuracy", 
                           refit=True, cv=5)

grid_search.fit(df["clean_review_comment_message"],df.review_score)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/tg/p4s0x3b55936405b1y1vws6h0000gn/T/ipykernel_9615/2267511281.py in <module>
#      19                            refit=True, cv=5)
#      20
# ---> 21 grid_search.fit(df["clean_review_comment_message"],df.review_score)
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     800         fit_params = _check_fit_params(X, fit_params)
#     801
# --> 802         cv_orig = check_cv(self.cv, y, classifier=is_classifier(estimator))
#     803         n_splits = cv_orig.get_n_splits(X, y, groups)
#     804
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/model_selection/_split.py in check_cv(cv, y, classifier)
#    2301             classifier
#    2302             and (y is not None)
# ...

# %%
grid_search.best_params_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/tg/p4s0x3b55936405b1y1vws6h0000gn/T/ipykernel_9615/758359460.py in <module>
# ----> 1 grid_search.best_params_
#
# AttributeError: 'GridSearchCV' object has no attribute 'best_params_'
