# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib

# %%
import requests

url ="https://iex.lewagon.com/stable/stock/aapl/chart/3m"
api_data= requests.get (url).json()
api_data
# Out:
# [{'close': 148.56,
#   'high': 148.7177,
#   'low': 146.92,
#   'open': 147.55,
#   'symbol': 'AAPL',
#   'volume': 71447416,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AAPL',
#   'subkey': '',
#   'date': '2021-07-23',
#   'updated': 1628263045000,
#   'changeOverTime': 0,
#   'marketChangeOverTime': 0,
#   'uOpen': 147.55,
#   'uClose': 148.56,
#   'uHigh': 148.7177,
#   'uLow': 146.92,
#   'uVolume': 71447416,
#   'fOpen': 147.3293,
#   'fClose': 148.3378,
#   'fHigh': 148.4952,
#   'fLow': 146.7002,
#   'fVolume': 71447416,
#   'label': 'Jul 23, 21',
#   'change': 0,
#   'changePercent': 0},
#  {'close': 148.99,
#   'high': 149.83,
#   'low': 147.7,
#   'open': 148.27,
#   'symbol': 'AAPL',
#   'volume': 72434089,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AAPL',
#   'subkey': '',
#   'date': '2021-07-26',
#   'updated': 1628262969000,
#   'changeOverTime': 0.0028944534194938532,
#   'marketChangeOverTime': 0.0028944534194938532,
#   'uOpen': 148.27,
#   'uClose': 148.99,
#   'uHigh': 149.83,
#   'uLow': 147.7,
#   'uVolume': 72434089,
#   'fOpen': 148.0482,
#   'fClose': 148.7671,
#   'fHigh': 149.6059,
#   'fLow': 147.479,
#   'fVolume': 72434089,
#   'label': 'Jul 26, 21',
#   'change': 0.4300000000000068,
#   'changePercent': 0.0029},
#  {'close': 146.77,
#   'high': 149.21,
#   'low': 145.55,
#   'open': 149.12,
#   'symbol': 'AAPL',
#   'volume': 104818578,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AAPL',
#   'subkey': '',
#   'date': '2021-07-27',
#   'updated': 1628263045000,
#   'changeOverTime': -0.012049003769520679,
#   'marketChangeOverTime': -0.012049003769520679,
#   'uOpen': 149.12,
#   'uClose': 146.77,
#   'uHigh': 149.21,
#   'uLow': 145.55,
#   'uVolume': 104818578,
#   'fOpen': 148.8969,
#   'fClose': 146.5504,
#   'fHigh': 148.9868,
#   'fLow': 145.3323,
#   'fVolume': 104818578,
#   'label': 'Jul 27, 21',
#   'change': -2.219999999999999,
#   'changePercent': -0.0149},
#  {'close': 144.98,
#   'high': 146.97,
#   'low': 142.54,
#   'open': 144.81,
#   'symbol': 'AAPL',
#   'volume': 118931191,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AAPL',
#   'subkey': '',
#   'date': '2021-07-28',
#   'updated': 1628263067000,
#   'changeOverTime': -0.02409800753904155,
#   'marketChangeOverTime': -0.02409800753904155,
#   'uOpen': 144.81,
#   'uClose': 144.98,
#   'uHigh': 146.97,
#   'uLow': 142.54,
#   'uVolume': 118931191,
#   'fOpen': 144.5934,
#   'fClose': 144.7631,
#   'fHigh': 146.7501,
#   'fLow': 142.3268,
#   'fVolume': 118931191,
#   'label': 'Jul 28, 21',
#   'change': -1.7900000000000205,
#   'changePercent': -0.0122},
#  {'close': 145.64,
#   'high': 146.55,
#   'low': 144.58,
#   'open': 144.685,
#   'symbol': 'AAPL',
#   'volume': 56699475,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AAPL',
#   'subkey': '',
#   'date': '2021-07-29',
#   'updated': 1628262969000,
#   'changeOverTime': -0.01965535810446968,
#   'marketChangeOverTime': -0.01965535810446968,
#   'uOpen': 144.685,
#   'uClose': 145.64,
#   'uHigh': 146.55,
#   'uLow': 144.58,
#   'uVolume': 56699475,
#   'fOpen': 144.4686,
#   'fClose': 145.4221,
#   'fHigh': 146.3308,
#   'fLow': 144.3637,
#   'fVolume': 56699475,
#   'label': 'Jul 29, 21',
#   'change': 0.6599999999999966,
#   'changePercent': 0.0046},
#  {'close': 145.86,
#   'high': 146.33,
#   'low': 144.11,
#   'open': 144.38,
#   'symbol': 'AAPL',
#   'volume': 70440626,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AAPL',
#   'subkey': '',
#   'date': '2021-07-30',
#   'updated': 1628263089000,
#   'changeOverTime': -0.0181744749596122,
#   'marketChangeOverTime': -0.0181744749596122,
#   'uOpen': 144.38,
#   'uClose': 145.86,
#   'uHigh': 146.33,
#   'uLow': 144.11,
#   'uVolume': 70440626,
#   'fOpen': 144.164,
#   'fClose': 145.6418,
#   'fHigh': 146.1111,
#   'fLow': 143.8944,
#   'fVolume': 70440626,
#   'label': 'Jul 30, 21',
#   'change': 0.22000000000002728,
#   'changePercent': 0.0015},
#  {'close': 145.52,
#   'high': 146.95,
#   'low': 145.25,
#   'open': 146.36,
#   'symbol': 'AAPL',
#   'volume': 62879961,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AAPL',
#   'subkey': '',
#   'date': '2021-08-02',
#   'updated': 1628263018000,
#   'changeOverTime': -0.020463112547118956,
#   'marketChangeOverTime': -0.020463112547118956,
#   'uOpen': 146.36,
#   'uClose': 145.52,
#   'uHigh': 146.95,
#   'uLow': 145.25,
#   'uVolume': 62879961,
#   'fOpen': 146.141,
#   'fClose': 145.3023,
#   'fHigh': 146.7302,
#   'fLow': 145.0327,
#   'fVolume': 62879961,
#   'label': 'Aug 2, 21',
#   'change': -0.3400000000000034,
#   'changePercent': -0.0023},
#  {'close': 147.36,
#   'high': 148.045,
#   'low': 145.18,
#   'open': 145.81,
#   'symbol': 'AAPL',
#   'volume': 64786618,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AAPL',
#   'subkey': '',
#   'date': '2021-08-03',
#   'updated': 1628263183000,
#   'changeOverTime': -0.00807754442649427,
#   'marketChangeOverTime': -0.00807754442649427,
#   'uOpen': 145.81,
#   'uClose': 147.36,
#   'uHigh': 148.045,
#   'uLow': 145.18,
#   'uVolume': 64786618,
#   'fOpen': 145.5919,
#   'fClose': 147.1396,
#   'fHigh': 147.8235,
#   'fLow': 144.9628,
#   'fVolume': 64786618,
#   'label': 'Aug 3, 21',
#   'change': 1.8400000000000034,
#   'changePercent': 0.0126},
#  {'close': 146.95,
#   'high': 147.79,
#   'low': 146.28,
#   'open': 147.27,
#   'symbol': 'AAPL',
#   'volume': 56368271,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AAPL',
#   'subkey': '',
#   'date': '2021-08-04',
#   'updated': 1628263122000,
#   'changeOverTime': -0.010837372105546672,
#   'marketChangeOverTime': -0.010837372105546672,
#   'uOpen': 147.27,
#   'uClose': 146.95,
#   'uHigh': 147.79,
#   'uLow': 146.28,
#   'uVolume': 56368271,
#   'fOpen': 147.0497,
#   'fClose': 146.7302,
#   'fHigh': 147.5689,
#   'fLow': 146.0612,
#   'fVolume': 56368271,
#   'label': 'Aug 4, 21',
#   'change': -0.410000000000025,
#   'changePercent': -0.0028},
#  {'close': 147.06,
#   'high': 147.84,
#   'low': 146.17,
#   'open': 146.98,
#   'symbol': 'AAPL',
#   'volume': 46397674,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AAPL',
#   'subkey': '',
#   'date': '2021-08-05',
#   'updated': 1628263183000,
#   'changeOverTime': -0.010096930533117932,
#   'marketChangeOverTime': -0.010096930533117932,
#   'uOpen': 146.98,
#   'uClose': 147.06,
#   'uHigh': 147.84,
#   'uLow': 146.17,
#   'uVolume': 46397674,
#   'fOpen': 146.7601,
#   'fClose': 146.84,
#   'fHigh': 147.6188,
#   'fLow': 145.9513,
#   'fVolume': 46397674,
#   'label': 'Aug 5, 21',
#   'change': 0.11000000000001364,
#   'changePercent': 0.0007},
#  {'close': 146.14,
#   'high': 147.11,
#   'low': 145.63,
#   'open': 146.35,
#   'symbol': 'AAPL',
#   'volume': 54126813,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AAPL',
#   'subkey': '',
#   'date': '2021-08-06',
#   'updated': 1628302613000,
#   'changeOverTime': -0.01628971459343037,
#   'marketChangeOverTime': -0.01628971459343037,
#   'uOpen': 146.35,
#   'uClose': 146.14,
#   'uHigh': 147.11,
#   'uLow': 145.63,
#   'uVolume': 54126813,
#   'fOpen': 146.35,
#   'fClose': 146.14,
#   'fHigh': 147.11,
#   'fLow': 145.63,
#   'fVolume': 54126813,
#   'label': 'Aug 6, 21',
#   'change': -0.9200000000000159,
#   'changePercent': -0.0063},
#  {'close': 146.09,
#   'high': 146.7,
#   'low': 145.52,
#   'open': 146.2,
#   'symbol': 'AAPL',
#   'volume': 48908689,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AAPL',
#   'subkey': '',
#   'date': '2021-08-09',
#   'updated': 1628557202000,
#   'changeOverTime': -0.016626278944534188,
#   'marketChangeOverTime': -0.016626278944534188,
#   'uOpen': 146.2,
#   'uClose': 146.09,
#   'uHigh': 146.7,
#   'uLow': 145.52,
#   'uVolume': 48908689,
#   'fOpen': 146.2,
#   'fClose': 146.09,
#   'fHigh': 146.7,
#   'fLow': 145.52,
#   'fVolume': 48908689,
#   'label': 'Aug 9, 21',
#   'change': -0.04999999999998295,
#   'changePercent': -0.0003},
#  {'close': 145.6,
#   'high': 147.71,
#   'low': 145.3,
#   'open': 146.44,
#   'symbol': 'AAPL',
#   'volume': 69023081,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AAPL',
#   'subkey': '',
#   'date': '2021-08-10',
#   'updated': 1628648173000,
#   'changeOverTime': -0.019924609585352773,
#   'marketChangeOverTime': -0.019924609585352773,
#   'uOpen': 146.44,
#   'uClose': 145.6,
#   'uHigh': 147.71,
#   'uLow': 145.3,
#   'uVolume': 69023081,
#   'fOpen': 146.44,
#   'fClose': 145.6,
#   'fHigh': 147.71,
#   'fLow': 145.3,
#   'fVolume': 69023081,
#   'label': 'Aug 10, 21',
#   'change': -0.4900000000000091,
#   'changePercent': -0.0034},
#  {'close': 145.86,
#   'high': 146.72,
#   'low': 145.53,
#   'open': 146.05,
#   'symbol': 'AAPL',
#   'volume': 48493463,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AAPL',
#   'subkey': '',
#   'date': '2021-08-11',
#   'updated': 1628730130000,
#   'changeOverTime': -0.0181744749596122,
#   'marketChangeOverTime': -0.0181744749596122,
#   'uOpen': 146.05,
#   'uClose': 145.86,
#   'uHigh': 146.72,
#   'uLow': 145.53,
#   'uVolume': 48493463,
#   'fOpen': 146.05,
#   'fClose': 145.86,
#   'fHigh': 146.72,
#   'fLow': 145.53,
#   'fVolume': 48493463,
#   'label': 'Aug 11, 21',
#   'change': 0.2600000000000193,
#   'changePercent': 0.0018},
#  {'close': 148.89,
#   'high': 149.05,
#   'low': 145.84,
#   'open': 146.19,
#   'symbol': 'AAPL',
#   'volume': 73779113,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AAPL',
#   'subkey': '',
#   'date': '2021-08-12',
#   'updated': 1628816415000,
#   'changeOverTime': 0.0022213247172858377,
#   'marketChangeOverTime': 0.0022213247172858377,
#   'uOpen': 146.19,
#   'uClose': 148.89,
#   'uHigh': 149.05,
#   'uLow': 145.84,
#   'uVolume': 73779113,
#   'fOpen': 146.19,
#   'fClose': 148.89,
#   'fHigh': 149.05,
#   'fLow': 145.84,
#   'fVolume': 73779113,
#   'label': 'Aug 12, 21',
#   'change': 3.0299999999999727,
#   'changePercent': 0.0208},
#  {'close': 149.1,
#   'high': 149.4444,
#   'low': 148.27,
#   'open': 148.97,
#   'symbol': 'AAPL',
#   'volume': 59375009,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AAPL',
#   'subkey': '',
#   'date': '2021-08-13',
#   'updated': 1629068395000,
#   'changeOverTime': 0.003634894991922402,
#   'marketChangeOverTime': 0.003634894991922402,
#   'uOpen': 148.97,
#   'uClose': 149.1,
#   'uHigh': 149.4444,
#   'uLow': 148.27,
#   'uVolume': 59375009,
#   'fOpen': 148.97,
#   'fClose': 149.1,
#   'fHigh': 149.4444,
#   'fLow': 148.27,
#   'fVolume': 59375009,
#   'label': 'Aug 13, 21',
#   'change': 0.21000000000000796,
#   'changePercent': 0.0014},
#  {'close': 151.12,
#   'high': 151.19,
#   'low': 146.47,
#   'open': 148.535,
#   'symbol': 'AAPL',
#   'volume': 103558782,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AAPL',
#   'subkey': '',
#   'date': '2021-08-16',
#   'updated': 1629162102000,
#   'changeOverTime': 0.017232094776521285,
#   'marketChangeOverTime': 0.017232094776521285,
#   'uOpen': 148.535,
#   'uClose': 151.12,
#   'uHigh': 151.19,
#   'uLow': 146.47,
#   'uVolume': 103558782,
#   'fOpen': 148.535,
#   'fClose': 151.12,
#   'fHigh': 151.19,
#   'fLow': 146.47,
#   'fVolume': 103558782,
#   'label': 'Aug 16, 21',
#   'change': 2.0200000000000102,
#   'changePercent': 0.0135},
#  {'close': 150.19,
#   'high': 151.68,
#   'low': 149.09,
#   'open': 150.23,
#   'symbol': 'AAPL',
#   'volume': 92229735,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AAPL',
#   'subkey': '',
#   'date': '2021-08-17',
#   'updated': 1629250326000,
#   'changeOverTime': 0.010971997845988122,
#   'marketChangeOverTime': 0.010971997845988122,
#   'uOpen': 150.23,
#   'uClose': 150.19,
#   'uHigh': 151.68,
#   'uLow': 149.09,
#   'uVolume': 92229735,
#   'fOpen': 150.23,
#   'fClose': 150.19,
#   'fHigh': 151.68,
#   'fLow': 149.09,
#   'fVolume': 92229735,
#   'label': 'Aug 17, 21',
#   'change': -0.9300000000000068,
#   'changePercent': -0.0062},
#  {'close': 146.36,
#   'high': 150.72,
#   'low': 146.15,
#   'open': 149.8,
#   'symbol': 'AAPL',
#   'volume': 86325990,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AAPL',
#   'subkey': '',
#   'date': '2021-08-18',
#   'updated': 1629334810000,
#   'changeOverTime': -0.01480883144857289,
#   'marketChangeOverTime': -0.01480883144857289,
#   'uOpen': 149.8,
#   'uClose': 146.36,
#   'uHigh': 150.72,
#   'uLow': 146.15,
#   'uVolume': 86325990,
#   'fOpen': 149.8,
#   'fClose': 146.36,
#   'fHigh': 150.72,
#   'fLow': 146.15,
#   'fVolume': 86325990,
#   'label': 'Aug 18, 21',
#   'change': -3.829999999999984,
#   'changePercent': -0.0255},
#  {'close': 146.7,
#   'high': 148,
#   'low': 144.5,
#   'open': 145.03,
#   'symbol': 'AAPL',
#   'volume': 86960310,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AAPL',
#   'subkey': '',
#   'date': '2021-08-19',
#   'updated': 1629421395000,
#   'changeOverTime': -0.012520193861066328,
#   'marketChangeOverTime': -0.012520193861066328,
#   'uOpen': 145.03,
#   'uClose': 146.7,
#   'uHigh': 148,
#   'uLow': 144.5,
#   'uVolume': 86960310,
#   'fOpen': 145.03,
#   'fClose': 146.7,
#   'fHigh': 148,
#   'fLow': 144.5,
#   'fVolume': 86960310,
#   'label': 'Aug 19, 21',
#   'change': 0.339999999999975,
#   'changePercent': 0.0023},
#  {'close': 148.19,
#   'high': 148.5,
#   'low': 146.78,
#   'open': 147.44,
#   'symbol': 'AAPL',
#   'volume': 60549630,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AAPL',
#   'subkey': '',
#   'date': '2021-08-20',
#   'updated': 1629508565000,
#   'changeOverTime': -0.0024905761981691204,
#   'marketChangeOverTime': -0.0024905761981691204,
#   'uOpen': 147.44,
#   'uClose': 148.19,
#   'uHigh': 148.5,
#   'uLow': 146.78,
#   'uVolume': 60549630,
#   'fOpen': 147.44,
#   'fClose': 148.19,
#   'fHigh': 148.5,
#   'fLow': 146.78,
#   'fVolume': 60549630,
#   'label': 'Aug 20, 21',
#   'change': 1.490000000000009,
#   'changePercent': 0.0102},
#  {'close': 149.71,
#   'high': 150.19,
#   'low': 147.89,
#   'open': 148.31,
#   'symbol': 'AAPL',
#   'volume': 60131810,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AAPL',
#   'subkey': '',
#   'date': '2021-08-23',
#   'updated': 1629768728000,
#   'changeOverTime': 0.007740980075390453,
#   'marketChangeOverTime': 0.007740980075390453,
#   'uOpen': 148.31,
#   'uClose': 149.71,
#   'uHigh': 150.19,
#   'uLow': 147.89,
#   'uVolume': 60131810,
#   'fOpen': 148.31,
#   'fClose': 149.71,
#   'fHigh': 150.19,
#   'fLow': 147.89,
#   'fVolume': 60131810,
#   'label': 'Aug 23, 21',
#   'change': 1.5200000000000102,
#   'changePercent': 0.0103},
#  {'close': 149.62,
#   'high': 150.86,
#   'low': 149.15,
#   'open': 149.45,
#   'symbol': 'AAPL',
#   'volume': 48606428,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AAPL',
#   'subkey': '',
#   'date': '2021-08-24',
#   'updated': 1629853204000,
#   'changeOverTime': 0.007135164243403354,
#   'marketChangeOverTime': 0.007135164243403354,
#   'uOpen': 149.45,
#   'uClose': 149.62,
#   'uHigh': 150.86,
#   'uLow': 149.15,
#   'uVolume': 48606428,
#   'fOpen': 149.45,
#   'fClose': 149.62,
#   'fHigh': 150.86,
#   'fLow': 149.15,
#   'fVolume': 48606428,
#   'label': 'Aug 24, 21',
#   'change': -0.09000000000000341,
#   'changePercent': -0.0006},
#  {'close': 148.36,
#   'high': 150.32,
#   'low': 147.8,
#   'open': 149.81,
#   'symbol': 'AAPL',
#   'volume': 58991297,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AAPL',
#   'subkey': '',
#   'date': '2021-08-25',
#   'updated': 1629939604000,
#   'changeOverTime': -0.0013462574044156477,
#   'marketChangeOverTime': -0.0013462574044156477,
#   'uOpen': 149.81,
#   'uClose': 148.36,
#   'uHigh': 150.32,
#   'uLow': 147.8,
#   'uVolume': 58991297,
#   'fOpen': 149.81,
#   'fClose': 148.36,
#   'fHigh': 150.32,
#   'fLow': 147.8,
#   'fVolume': 58991297,
#   'label': 'Aug 25, 21',
#   'change': -1.259999999999991,
#   'changePercent': -0.0084},
#  {'close': 147.54,
#   'high': 149.12,
#   'low': 147.51,
#   'open': 148.35,
#   'symbol': 'AAPL',
#   'volume': 48597195,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AAPL',
#   'subkey': '',
#   'date': '2021-08-26',
#   'updated': 1630026114000,
#   'changeOverTime': -0.006865912762520262,
#   'marketChangeOverTime': -0.006865912762520262,
#   'uOpen': 148.35,
#   'uClose': 147.54,
#   'uHigh': 149.12,
#   'uLow': 147.51,
#   'uVolume': 48597195,
#   'fOpen': 148.35,
#   'fClose': 147.54,
#   'fHigh': 149.12,
#   'fLow': 147.51,
#   'fVolume': 48597195,
#   'label': 'Aug 26, 21',
#   'change': -0.8200000000000216,
#   'changePercent': -0.0055},
#  {'close': 148.6,
#   'high': 148.75,
#   'low': 146.83,
#   'open': 147.48,
#   'symbol': 'AAPL',
#   'volume': 55802388,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AAPL',
#   'subkey': '',
#   'date': '2021-08-27',
#   'updated': 1630113784000,
#   'changeOverTime': 0.0002692514808830913,
#   'marketChangeOverTime': 0.0002692514808830913,
#   'uOpen': 147.48,
#   'uClose': 148.6,
#   'uHigh': 148.75,
#   'uLow': 146.83,
#   'uVolume': 55802388,
#   'fOpen': 147.48,
#   'fClose': 148.6,
#   'fHigh': 148.75,
#   'fLow': 146.83,
#   'fVolume': 55802388,
#   'label': 'Aug 27, 21',
#   'change': 1.0600000000000023,
#   'changePercent': 0.0072},
#  {'close': 153.12,
#   'high': 153.49,
#   'low': 148.61,
#   'open': 149,
#   'symbol': 'AAPL',
#   'volume': 90956723,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AAPL',
#   'subkey': '',
#   'date': '2021-08-30',
#   'updated': 1630371690000,
#   'changeOverTime': 0.03069466882067853,
#   'marketChangeOverTime': 0.03069466882067853,
#   'uOpen': 149,
#   'uClose': 153.12,
#   'uHigh': 153.49,
#   'uLow': 148.61,
#   'uVolume': 90956723,
#   'fOpen': 149,
#   'fClose': 153.12,
#   'fHigh': 153.49,
#   'fLow': 148.61,
#   'fVolume': 90956723,
#   'label': 'Aug 30, 21',
#   'change': 4.52000000000001,
#   'changePercent': 0.0304},
#  {'close': 151.83,
#   'high': 152.8,
#   'low': 151.29,
#   'open': 152.66,
#   'symbol': 'AAPL',
#   'volume': 86453117,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AAPL',
#   'subkey': '',
#   'date': '2021-08-31',
#   'updated': 1630457722000,
#   'changeOverTime': 0.02201130856219716,
#   'marketChangeOverTime': 0.02201130856219716,
#   'uOpen': 152.66,
#   'uClose': 151.83,
#   'uHigh': 152.8,
#   'uLow': 151.29,
#   'uVolume': 86453117,
#   'fOpen': 152.66,
#   'fClose': 151.83,
#   'fHigh': 152.8,
#   'fLow': 151.29,
#   'fVolume': 86453117,
#   'label': 'Aug 31, 21',
#   'change': -1.289999999999992,
#   'changePercent': -0.0084},
#  {'close': 152.51,
#   'high': 154.98,
#   'low': 152.34,
#   'open': 152.83,
#   'symbol': 'AAPL',
#   'volume': 80313711,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AAPL',
#   'subkey': '',
#   'date': '2021-09-01',
#   'updated': 1630543793000,
#   'changeOverTime': 0.02658858373721048,
#   'marketChangeOverTime': 0.02658858373721048,
#   'uOpen': 152.83,
#   'uClose': 152.51,
#   'uHigh': 154.98,
#   'uLow': 152.34,
#   'uVolume': 80313711,
#   'fOpen': 152.83,
#   'fClose': 152.51,
#   'fHigh': 154.98,
#   'fLow': 152.34,
#   'fVolume': 80313711,
#   'label': 'Sep 1, 21',
#   'change': 0.6799999999999784,
#   'changePercent': 0.0045},
#  {'close': 153.65,
#   'high': 154.72,
#   'low': 152.4,
#   'open': 153.87,
#   'symbol': 'AAPL',
#   'volume': 71171317,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AAPL',
#   'subkey': '',
#   'date': '2021-09-02',
#   'updated': 1630630188000,
#   'changeOverTime': 0.0342622509423802,
#   'marketChangeOverTime': 0.0342622509423802,
#   'uOpen': 153.87,
#   'uClose': 153.65,
#   'uHigh': 154.72,
#   'uLow': 152.4,
#   'uVolume': 71171317,
#   'fOpen': 153.87,
#   'fClose': 153.65,
#   'fHigh': 154.72,
#   'fLow': 152.4,
#   'fVolume': 71171317,
#   'label': 'Sep 2, 21',
#   'change': 1.1400000000000148,
#   'changePercent': 0.0075},
#  {'close': 154.3,
#   'high': 154.63,
#   'low': 153.09,
#   'open': 153.76,
#   'symbol': 'AAPL',
#   'volume': 57866066,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AAPL',
#   'subkey': '',
#   'date': '2021-09-03',
#   'updated': 1630718663000,
#   'changeOverTime': 0.038637587506731345,
#   'marketChangeOverTime': 0.038637587506731345,
#   'uOpen': 153.76,
#   'uClose': 154.3,
#   'uHigh': 154.63,
#   'uLow': 153.09,
#   'uVolume': 57866066,
#   'fOpen': 153.76,
#   'fClose': 154.3,
#   'fHigh': 154.63,
#   'fLow': 153.09,
#   'fVolume': 57866066,
#   'label': 'Sep 3, 21',
#   'change': 0.6500000000000057,
#   'changePercent': 0.0042},
#  {'close': 156.69,
#   'high': 157.26,
#   'low': 154.39,
#   'open': 154.97,
#   'symbol': 'AAPL',
#   'volume': 82278261,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AAPL',
#   'subkey': '',
#   'date': '2021-09-07',
#   'updated': 1631063411000,
#   'changeOverTime': 0.05472536348949916,
#   'marketChangeOverTime': 0.05472536348949916,
#   'uOpen': 154.97,
#   'uClose': 156.69,
#   'uHigh': 157.26,
#   'uLow': 154.39,
#   'uVolume': 82278261,
#   'fOpen': 154.97,
#   'fClose': 156.69,
#   'fHigh': 157.26,
#   'fLow': 154.39,
#   'fVolume': 82278261,
#   'label': 'Sep 7, 21',
#   'change': 2.3899999999999864,
#   'changePercent': 0.0155},
#  {'close': 155.11,
#   'high': 157.04,
#   'low': 153.975,
#   'open': 156.98,
#   'symbol': 'AAPL',
#   'volume': 74420207,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AAPL',
#   'subkey': '',
#   'date': '2021-09-08',
#   'updated': 1631148569000,
#   'changeOverTime': 0.04408992999461504,
#   'marketChangeOverTime': 0.04408992999461504,
#   'uOpen': 156.98,
#   'uClose': 155.11,
#   'uHigh': 157.04,
#   'uLow': 153.975,
#   'uVolume': 74420207,
#   'fOpen': 156.98,
#   'fClose': 155.11,
#   'fHigh': 157.04,
#   'fLow': 153.975,
#   'fVolume': 74420207,
#   'label': 'Sep 8, 21',
#   'change': -1.579999999999984,
#   'changePercent': -0.0101},
#  {'close': 154.07,
#   'high': 156.11,
#   'low': 153.95,
#   'open': 155.49,
#   'symbol': 'AAPL',
#   'volume': 57305730,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AAPL',
#   'subkey': '',
#   'date': '2021-09-09',
#   'updated': 1631234971000,
#   'changeOverTime': 0.03708939149165314,
#   'marketChangeOverTime': 0.03708939149165314,
#   'uOpen': 155.49,
#   'uClose': 154.07,
#   'uHigh': 156.11,
#   'uLow': 153.95,
#   'uVolume': 57305730,
#   'fOpen': 155.49,
#   'fClose': 154.07,
#   'fHigh': 156.11,
#   'fLow': 153.95,
#   'fVolume': 57305730,
#   'label': 'Sep 9, 21',
#   'change': -1.0400000000000205,
#   'changePercent': -0.0067},
#  {'close': 148.97,
#   'high': 155.48,
#   'low': 148.7,
#   'open': 155,
#   'symbol': 'AAPL',
#   'volume': 140893235,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AAPL',
#   'subkey': '',
#   'date': '2021-09-10',
#   'updated': 1631323064000,
#   'changeOverTime': 0.002759827679052212,
#   'marketChangeOverTime': 0.002759827679052212,
#   'uOpen': 155,
#   'uClose': 148.97,
#   'uHigh': 155.48,
#   'uLow': 148.7,
#   'uVolume': 140893235,
#   'fOpen': 155,
#   'fClose': 148.97,
#   'fHigh': 155.48,
#   'fLow': 148.7,
#   'fVolume': 140893235,
#   'label': 'Sep 10, 21',
#   'change': -5.099999999999994,
#   'changePercent': -0.0331},
#  {'close': 149.55,
#   'high': 151.42,
#   'low': 148.75,
#   'open': 150.63,
#   'symbol': 'AAPL',
#   'volume': 102404329,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AAPL',
#   'subkey': '',
#   'date': '2021-09-13',
#   'updated': 1631580586000,
#   'changeOverTime': 0.0066639741518578965,
#   'marketChangeOverTime': 0.0066639741518578965,
#   'uOpen': 150.63,
#   'uClose': 149.55,
#   'uHigh': 151.42,
#   'uLow': 148.75,
#   'uVolume': 102404329,
#   'fOpen': 150.63,
#   'fClose': 149.55,
#   'fHigh': 151.42,
#   'fLow': 148.75,
#   'fVolume': 102404329,
#   'label': 'Sep 13, 21',
#   'change': 0.5800000000000125,
#   'changePercent': 0.0039},
#  {'close': 148.12,
#   'high': 151.07,
#   'low': 146.91,
#   'open': 150.35,
#   'symbol': 'AAPL',
#   'volume': 109296295,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AAPL',
#   'subkey': '',
#   'date': '2021-09-14',
#   'updated': 1631668519000,
#   'changeOverTime': -0.002961766289714578,
#   'marketChangeOverTime': -0.002961766289714578,
#   'uOpen': 150.35,
#   'uClose': 148.12,
#   'uHigh': 151.07,
#   'uLow': 146.91,
#   'uVolume': 109296295,
#   'fOpen': 150.35,
#   'fClose': 148.12,
#   'fHigh': 151.07,
#   'fLow': 146.91,
#   'fVolume': 109296295,
#   'label': 'Sep 14, 21',
#   'change': -1.4300000000000068,
#   'changePercent': -0.0096},
#  {'close': 149.03,
#   'high': 149.44,
#   'low': 146.37,
#   'open': 148.56,
#   'symbol': 'AAPL',
#   'volume': 83281315,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AAPL',
#   'subkey': '',
#   'date': '2021-09-15',
#   'updated': 1631753715000,
#   'changeOverTime': 0.0031637049003769443,
#   'marketChangeOverTime': 0.0031637049003769443,
#   'uOpen': 148.56,
#   'uClose': 149.03,
#   'uHigh': 149.44,
#   'uLow': 146.37,
#   'uVolume': 83281315,
#   'fOpen': 148.56,
#   'fClose': 149.03,
#   'fHigh': 149.44,
#   'fLow': 146.37,
#   'fVolume': 83281315,
#   'label': 'Sep 15, 21',
#   'change': 0.9099999999999966,
#   'changePercent': 0.0061},
#  {'close': 148.79,
#   'high': 148.97,
#   'low': 147.221,
#   'open': 148.44,
#   'symbol': 'AAPL',
#   'volume': 68034149,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AAPL',
#   'subkey': '',
#   'date': '2021-09-16',
#   'updated': 1631839770000,
#   'changeOverTime': 0.001548196015078014,
#   'marketChangeOverTime': 0.001548196015078014,
#   'uOpen': 148.44,
#   'uClose': 148.79,
#   'uHigh': 148.97,
#   'uLow': 147.221,
#   'uVolume': 68034149,
#   'fOpen': 148.44,
#   'fClose': 148.79,
#   'fHigh': 148.97,
#   'fLow': 147.221,
#   'fVolume': 68034149,
#   'label': 'Sep 16, 21',
#   'change': -0.2400000000000091,
#   'changePercent': -0.0016},
#  {'close': 146.06,
#   'high': 148.82,
#   'low': 145.76,
#   'open': 148.82,
#   'symbol': 'AAPL',
#   'volume': 129868824,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AAPL',
#   'subkey': '',
#   'date': '2021-09-17',
#   'updated': 1631931496000,
#   'changeOverTime': -0.016828217555196555,
#   'marketChangeOverTime': -0.016828217555196555,
#   'uOpen': 148.82,
#   'uClose': 146.06,
#   'uHigh': 148.82,
#   'uLow': 145.76,
#   'uVolume': 129868824,
#   'fOpen': 148.82,
#   'fClose': 146.06,
#   'fHigh': 148.82,
#   'fLow': 145.76,
#   'fVolume': 129868824,
#   'label': 'Sep 17, 21',
#   'change': -2.7299999999999898,
#   'changePercent': -0.0183},
#  {'close': 142.94,
#   'high': 144.84,
#   'low': 141.27,
#   'open': 143.8,
#   'symbol': 'AAPL',
#   'volume': 123478863,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AAPL',
#   'subkey': '',
#   'date': '2021-09-20',
#   'updated': 1632185607000,
#   'changeOverTime': -0.037829833064081886,
#   'marketChangeOverTime': -0.037829833064081886,
#   'uOpen': 143.8,
#   'uClose': 142.94,
#   'uHigh': 144.84,
#   'uLow': 141.27,
#   'uVolume': 123478863,
#   'fOpen': 143.8,
#   'fClose': 142.94,
#   'fHigh': 144.84,
#   'fLow': 141.27,
#   'fVolume': 123478863,
#   'label': 'Sep 20, 21',
#   'change': -3.1200000000000045,
#   'changePercent': -0.0214},
#  {'close': 143.43,
#   'high': 144.6,
#   'low': 142.78,
#   'open': 143.93,
#   'symbol': 'AAPL',
#   'volume': 75833962,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AAPL',
#   'subkey': '',
#   'date': '2021-09-21',
#   'updated': 1632275359000,
#   'changeOverTime': -0.0345315024232633,
#   'marketChangeOverTime': -0.0345315024232633,
#   'uOpen': 143.93,
#   'uClose': 143.43,
#   'uHigh': 144.6,
#   'uLow': 142.78,
#   'uVolume': 75833962,
#   'fOpen': 143.93,
#   'fClose': 143.43,
#   'fHigh': 144.6,
#   'fLow': 142.78,
#   'fVolume': 75833962,
#   'label': 'Sep 21, 21',
#   'change': 0.4900000000000091,
#   'changePercent': 0.0034},
#  {'close': 145.85,
#   'high': 146.43,
#   'low': 143.7001,
#   'open': 144.45,
#   'symbol': 'AAPL',
#   'volume': 76404341,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AAPL',
#   'subkey': '',
#   'date': '2021-09-22',
#   'updated': 1632360772000,
#   'changeOverTime': -0.018241787829833118,
#   'marketChangeOverTime': -0.018241787829833118,
#   'uOpen': 144.45,
#   'uClose': 145.85,
#   'uHigh': 146.43,
#   'uLow': 143.7001,
#   'uVolume': 76404341,
#   'fOpen': 144.45,
#   'fClose': 145.85,
#   'fHigh': 146.43,
#   'fLow': 143.7001,
#   'fVolume': 76404341,
#   'label': 'Sep 22, 21',
#   'change': 2.4199999999999875,
#   'changePercent': 0.0169},
#  {'close': 146.83,
#   'high': 147.08,
#   'low': 145.64,
#   'open': 146.65,
#   'symbol': 'AAPL',
#   'volume': 64838170,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AAPL',
#   'subkey': '',
#   'date': '2021-09-23',
#   'updated': 1632455411000,
#   'changeOverTime': -0.011645126548195946,
#   'marketChangeOverTime': -0.011645126548195946,
#   'uOpen': 146.65,
#   'uClose': 146.83,
#   'uHigh': 147.08,
#   'uLow': 145.64,
#   'uVolume': 64838170,
#   'fOpen': 146.65,
#   'fClose': 146.83,
#   'fHigh': 147.08,
#   'fLow': 145.64,
#   'fVolume': 64838170,
#   'label': 'Sep 23, 21',
#   'change': 0.9800000000000182,
#   'changePercent': 0.0067},
#  {'close': 146.92,
#   'high': 147.4701,
#   'low': 145.56,
#   'open': 145.66,
#   'symbol': 'AAPL',
#   'volume': 53477869,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AAPL',
#   'subkey': '',
#   'date': '2021-09-24',
#   'updated': 1632550861000,
#   'changeOverTime': -0.011039310716209038,
#   'marketChangeOverTime': -0.011039310716209038,
#   'uOpen': 145.66,
#   'uClose': 146.92,
#   'uHigh': 147.4701,
#   'uLow': 145.56,
#   'uVolume': 53477869,
#   'fOpen': 145.66,
#   'fClose': 146.92,
#   'fHigh': 147.4701,
#   'fLow': 145.56,
#   'fVolume': 53477869,
#   'label': 'Sep 24, 21',
#   'change': 0.08999999999997499,
#   'changePercent': 0.0006},
#  {'close': 145.37,
#   'high': 145.96,
#   'low': 143.82,
#   'open': 145.47,
#   'symbol': 'AAPL',
#   'volume': 74150729,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AAPL',
#   'subkey': '',
#   'date': '2021-09-27',
#   'updated': 1632797430000,
#   'changeOverTime': -0.021472805600430786,
#   'marketChangeOverTime': -0.021472805600430786,
#   'uOpen': 145.47,
#   'uClose': 145.37,
#   'uHigh': 145.96,
#   'uLow': 143.82,
#   'uVolume': 74150729,
#   'fOpen': 145.47,
#   'fClose': 145.37,
#   'fHigh': 145.96,
#   'fLow': 143.82,
#   'fVolume': 74150729,
#   'label': 'Sep 27, 21',
#   'change': -1.549999999999983,
#   'changePercent': -0.0105},
#  {'close': 141.91,
#   'high': 144.75,
#   'low': 141.69,
#   'open': 143.25,
#   'symbol': 'AAPL',
#   'volume': 108972340,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AAPL',
#   'subkey': '',
#   'date': '2021-09-28',
#   'updated': 1632877519000,
#   'changeOverTime': -0.04476305869682287,
#   'marketChangeOverTime': -0.04476305869682287,
#   'uOpen': 143.25,
#   'uClose': 141.91,
#   'uHigh': 144.75,
#   'uLow': 141.69,
#   'uVolume': 108972340,
#   'fOpen': 143.25,
#   'fClose': 141.91,
#   'fHigh': 144.75,
#   'fLow': 141.69,
#   'fVolume': 108972340,
#   'label': 'Sep 28, 21',
#   'change': -3.460000000000008,
#   'changePercent': -0.0238},
#  {'close': 142.83,
#   'high': 144.45,
#   'low': 142.03,
#   'open': 142.47,
#   'symbol': 'AAPL',
#   'volume': 74602044,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AAPL',
#   'subkey': '',
#   'date': '2021-09-29',
#   'updated': 1632963935000,
#   'changeOverTime': -0.03857027463651043,
#   'marketChangeOverTime': -0.03857027463651043,
#   'uOpen': 142.47,
#   'uClose': 142.83,
#   'uHigh': 144.45,
#   'uLow': 142.03,
#   'uVolume': 74602044,
#   'fOpen': 142.47,
#   'fClose': 142.83,
#   'fHigh': 144.45,
#   'fLow': 142.03,
#   'fVolume': 74602044,
#   'label': 'Sep 29, 21',
#   'change': 0.9200000000000159,
#   'changePercent': 0.0065},
#  {'close': 141.5,
#   'high': 144.378,
#   'low': 141.28,
#   'open': 143.66,
#   'symbol': 'AAPL',
#   'volume': 89056664,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AAPL',
#   'subkey': '',
#   'date': '2021-09-30',
#   'updated': 1633049568000,
#   'changeOverTime': -0.04752288637587508,
#   'marketChangeOverTime': -0.04752288637587508,
#   'uOpen': 143.66,
#   'uClose': 141.5,
#   'uHigh': 144.378,
#   'uLow': 141.28,
#   'uVolume': 89056664,
#   'fOpen': 143.66,
#   'fClose': 141.5,
#   'fHigh': 144.378,
#   'fLow': 141.28,
#   'fVolume': 89056664,
#   'label': 'Sep 30, 21',
#   'change': -1.3300000000000125,
#   'changePercent': -0.0093},
#  {'close': 142.65,
#   'high': 142.92,
#   'low': 139.1101,
#   'open': 141.9,
#   'symbol': 'AAPL',
#   'volume': 94639581,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AAPL',
#   'subkey': '',
#   'date': '2021-10-01',
#   'updated': 1633137668000,
#   'changeOverTime': -0.03978190630048463,
#   'marketChangeOverTime': -0.03978190630048463,
#   'uOpen': 141.9,
#   'uClose': 142.65,
#   'uHigh': 142.92,
#   'uLow': 139.1101,
#   'uVolume': 94639581,
#   'fOpen': 141.9,
#   'fClose': 142.65,
#   'fHigh': 142.92,
#   'fLow': 139.1101,
#   'fVolume': 94639581,
#   'label': 'Oct 1, 21',
#   'change': 1.1500000000000057,
#   'changePercent': 0.0081},
#  {'close': 139.14,
#   'high': 142.21,
#   'low': 138.27,
#   'open': 141.76,
#   'symbol': 'AAPL',
#   'volume': 98322008,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AAPL',
#   'subkey': '',
#   'date': '2021-10-04',
#   'updated': 1633399548000,
#   'changeOverTime': -0.06340872374798072,
#   'marketChangeOverTime': -0.06340872374798072,
#   'uOpen': 141.76,
#   'uClose': 139.14,
#   'uHigh': 142.21,
#   'uLow': 138.27,
#   'uVolume': 98322008,
#   'fOpen': 141.76,
#   'fClose': 139.14,
#   'fHigh': 142.21,
#   'fLow': 138.27,
#   'fVolume': 98322008,
#   'label': 'Oct 4, 21',
#   'change': -3.5100000000000193,
#   'changePercent': -0.0246},
#  {'close': 141.11,
#   'high': 142.24,
#   'low': 139.36,
#   'open': 139.49,
#   'symbol': 'AAPL',
#   'volume': 80861062,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AAPL',
#   'subkey': '',
#   'date': '2021-10-05',
#   'updated': 1633484350000,
#   'changeOverTime': -0.05014808831448565,
#   'marketChangeOverTime': -0.05014808831448565,
#   'uOpen': 139.49,
#   'uClose': 141.11,
#   'uHigh': 142.24,
#   'uLow': 139.36,
#   'uVolume': 80861062,
#   'fOpen': 139.49,
#   'fClose': 141.11,
#   'fHigh': 142.24,
#   'fLow': 139.36,
#   'fVolume': 80861062,
#   'label': 'Oct 5, 21',
#   'change': 1.9700000000000273,
#   'changePercent': 0.0142},
#  {'close': 142,
#   'high': 142.15,
#   'low': 138.37,
#   'open': 139.47,
#   'symbol': 'AAPL',
#   'volume': 83221119,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AAPL',
#   'subkey': '',
#   'date': '2021-10-06',
#   'updated': 1633570596000,
#   'changeOverTime': -0.04415724286483577,
#   'marketChangeOverTime': -0.04415724286483577,
#   'uOpen': 139.47,
#   'uClose': 142,
#   'uHigh': 142.15,
#   'uLow': 138.37,
#   'uVolume': 83221119,
#   'fOpen': 139.47,
#   'fClose': 142,
#   'fHigh': 142.15,
#   'fLow': 138.37,
#   'fVolume': 83221119,
#   'label': 'Oct 6, 21',
#   'change': 0.8899999999999864,
#   'changePercent': 0.0063},
#  {'close': 143.29,
#   'high': 144.215,
#   'low': 142.72,
#   'open': 143.06,
#   'symbol': 'AAPL',
#   'volume': 61732656,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AAPL',
#   'subkey': '',
#   'date': '2021-10-07',
#   'updated': 1633656987000,
#   'changeOverTime': -0.0354738826063544,
#   'marketChangeOverTime': -0.0354738826063544,
#   'uOpen': 143.06,
#   'uClose': 143.29,
#   'uHigh': 144.215,
#   'uLow': 142.72,
#   'uVolume': 61732656,
#   'fOpen': 143.06,
#   'fClose': 143.29,
#   'fHigh': 144.215,
#   'fLow': 142.72,
#   'fVolume': 61732656,
#   'label': 'Oct 7, 21',
#   'change': 1.289999999999992,
#   'changePercent': 0.0091},
#  {'close': 142.9,
#   'high': 144.1781,
#   'low': 142.56,
#   'open': 144.03,
#   'symbol': 'AAPL',
#   'volume': 58773155,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AAPL',
#   'subkey': '',
#   'date': '2021-10-08',
#   'updated': 1633742309000,
#   'changeOverTime': -0.038099084544964974,
#   'marketChangeOverTime': -0.038099084544964974,
#   'uOpen': 144.03,
#   'uClose': 142.9,
#   'uHigh': 144.1781,
#   'uLow': 142.56,
#   'uVolume': 58773155,
#   'fOpen': 144.03,
#   'fClose': 142.9,
#   'fHigh': 144.1781,
#   'fLow': 142.56,
#   'fVolume': 58773155,
#   'label': 'Oct 8, 21',
#   'change': -0.38999999999998636,
#   'changePercent': -0.0027},
#  {'close': 142.81,
#   'high': 144.81,
#   'low': 141.81,
#   'open': 142.27,
#   'symbol': 'AAPL',
#   'volume': 64452219,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AAPL',
#   'subkey': '',
#   'date': '2021-10-11',
#   'updated': 1634000540000,
#   'changeOverTime': -0.038704900376952074,
#   'marketChangeOverTime': -0.038704900376952074,
#   'uOpen': 142.27,
#   'uClose': 142.81,
#   'uHigh': 144.81,
#   'uLow': 141.81,
#   'uVolume': 64452219,
#   'fOpen': 142.27,
#   'fClose': 142.81,
#   'fHigh': 144.81,
#   'fLow': 141.81,
#   'fVolume': 64452219,
#   'label': 'Oct 11, 21',
#   'change': -0.09000000000000341,
#   'changePercent': -0.0006},
#  {'close': 141.51,
#   'high': 143.25,
#   'low': 141.0401,
#   'open': 143.23,
#   'symbol': 'AAPL',
#   'volume': 73035859,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AAPL',
#   'subkey': '',
#   'date': '2021-10-12',
#   'updated': 1634088834000,
#   'changeOverTime': -0.04745557350565436,
#   'marketChangeOverTime': -0.04745557350565436,
#   'uOpen': 143.23,
#   'uClose': 141.51,
#   'uHigh': 143.25,
#   'uLow': 141.0401,
#   'uVolume': 73035859,
#   'fOpen': 143.23,
#   'fClose': 141.51,
#   'fHigh': 143.25,
#   'fLow': 141.0401,
#   'fVolume': 73035859,
#   'label': 'Oct 12, 21',
#   'change': -1.3000000000000114,
#   'changePercent': -0.0091},
#  {'close': 140.91,
#   'high': 141.4,
#   'low': 139.2,
#   'open': 141.235,
#   'symbol': 'AAPL',
#   'volume': 78762721,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AAPL',
#   'subkey': '',
#   'date': '2021-10-13',
#   'updated': 1634173757000,
#   'changeOverTime': -0.05149434571890149,
#   'marketChangeOverTime': -0.05149434571890149,
#   'uOpen': 141.235,
#   'uClose': 140.91,
#   'uHigh': 141.4,
#   'uLow': 139.2,
#   'uVolume': 78762721,
#   'fOpen': 141.235,
#   'fClose': 140.91,
#   'fHigh': 141.4,
#   'fLow': 139.2,
#   'fVolume': 78762721,
#   'label': 'Oct 13, 21',
#   'change': -0.5999999999999943,
#   'changePercent': -0.0042},
#  {'close': 143.76,
#   'high': 143.88,
#   'low': 141.51,
#   'open': 142.11,
#   'symbol': 'AAPL',
#   'volume': 69907100,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AAPL',
#   'subkey': '',
#   'date': '2021-10-14',
#   'updated': 1634260049000,
#   'changeOverTime': -0.03231017770597746,
#   'marketChangeOverTime': -0.03231017770597746,
#   'uOpen': 142.11,
#   'uClose': 143.76,
#   'uHigh': 143.88,
#   'uLow': 141.51,
#   'uVolume': 69907100,
#   'fOpen': 142.11,
#   'fClose': 143.76,
#   'fHigh': 143.88,
#   'fLow': 141.51,
#   'fVolume': 69907100,
#   'label': 'Oct 14, 21',
#   'change': 2.8499999999999943,
#   'changePercent': 0.0202},
#  {'close': 144.84,
#   'high': 144.895,
#   'low': 143.51,
#   'open': 143.77,
#   'symbol': 'AAPL',
#   'volume': 67940334,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AAPL',
#   'subkey': '',
#   'date': '2021-10-15',
#   'updated': 1634347014000,
#   'changeOverTime': -0.025040387722132462,
#   'marketChangeOverTime': -0.025040387722132462,
#   'uOpen': 143.77,
#   'uClose': 144.84,
#   'uHigh': 144.895,
#   'uLow': 143.51,
#   'uVolume': 67940334,
#   'fOpen': 143.77,
#   'fClose': 144.84,
#   'fHigh': 144.895,
#   'fLow': 143.51,
#   'fVolume': 67940334,
#   'label': 'Oct 15, 21',
#   'change': 1.0800000000000125,
#   'changePercent': 0.0075},
#  {'close': 146.55,
#   'high': 146.84,
#   'low': 143.16,
#   'open': 143.445,
#   'symbol': 'AAPL',
#   'volume': 85589175,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AAPL',
#   'subkey': '',
#   'date': '2021-10-18',
#   'updated': 1634605250000,
#   'changeOverTime': -0.013529886914377967,
#   'marketChangeOverTime': -0.013529886914377967,
#   'uOpen': 143.445,
#   'uClose': 146.55,
#   'uHigh': 146.84,
#   'uLow': 143.16,
#   'uVolume': 85589175,
#   'fOpen': 143.445,
#   'fClose': 146.55,
#   'fHigh': 146.84,
#   'fLow': 143.16,
#   'fVolume': 85589175,
#   'label': 'Oct 18, 21',
#   'change': 1.710000000000008,
#   'changePercent': 0.0118},
#  {'close': 148.76,
#   'high': 149.17,
#   'low': 146.55,
#   'open': 147.01,
#   'symbol': 'AAPL',
#   'volume': 76378894,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AAPL',
#   'subkey': '',
#   'date': '2021-10-19',
#   'updated': 1634692665000,
#   'changeOverTime': 0.0013462574044156477,
#   'marketChangeOverTime': 0.0013462574044156477,
#   'uOpen': 147.01,
#   'uClose': 148.76,
#   'uHigh': 149.17,
#   'uLow': 146.55,
#   'uVolume': 76378894,
#   'fOpen': 147.01,
#   'fClose': 148.76,
#   'fHigh': 149.17,
#   'fLow': 146.55,
#   'fVolume': 76378894,
#   'label': 'Oct 19, 21',
#   'change': 2.2099999999999795,
#   'changePercent': 0.0151},
#  {'close': 149.26,
#   'high': 149.7539,
#   'low': 148.12,
#   'open': 148.7,
#   'symbol': 'AAPL',
#   'volume': 58418788,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AAPL',
#   'subkey': '',
#   'date': '2021-10-20',
#   'updated': 1634778299000,
#   'changeOverTime': 0.004711900915454958,
#   'marketChangeOverTime': 0.004711900915454958,
#   'uOpen': 148.7,
#   'uClose': 149.26,
#   'uHigh': 149.7539,
#   'uLow': 148.12,
#   'uVolume': 58418788,
#   'fOpen': 148.7,
#   'fClose': 149.26,
#   'fHigh': 149.7539,
#   'fLow': 148.12,
#   'fVolume': 58418788,
#   'label': 'Oct 20, 21',
#   'change': 0.5,
#   'changePercent': 0.0034},
#  {'close': 149.48,
#   'high': 149.64,
#   'low': 147.87,
#   'open': 148.81,
#   'symbol': 'AAPL',
#   'volume': 61420990,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AAPL',
#   'subkey': '',
#   'date': '2021-10-21',
#   'updated': 1634864601000,
#   'changeOverTime': 0.006192784060312247,
#   'marketChangeOverTime': 0.006192784060312247,
#   'uOpen': 148.81,
#   'uClose': 149.48,
#   'uHigh': 149.64,
#   'uLow': 147.87,
#   'uVolume': 61420990,
#   'fOpen': 148.81,
#   'fClose': 149.48,
#   'fHigh': 149.64,
#   'fLow': 147.87,
#   'fVolume': 61420990,
#   'label': 'Oct 21, 21',
#   'change': 0.21999999999999886,
#   'changePercent': 0.0015},
#  {'close': 148.69,
#   'high': 150.18,
#   'low': 148.64,
#   'open': 149.69,
#   'symbol': 'AAPL',
#   'volume': 58883443,
#   'id': 'HISTORICAL_PRICES',
#   'key': 'AAPL',
#   'subkey': '',
#   'date': '2021-10-22',
#   'updated': 1634951877000,
#   'changeOverTime': 0.0008750673128701901,
#   'marketChangeOverTime': 0.0008750673128701901,
#   'uOpen': 149.69,
#   'uClose': 148.69,
#   'uHigh': 150.18,
#   'uLow': 148.64,
#   'uVolume': 58883443,
#   'fOpen': 149.69,
#   'fClose': 148.69,
#   'fHigh': 150.18,
#   'fLow': 148.64,
#   'fVolume': 58883443,
#   'label': 'Oct 22, 21',
#   'change': -0.789999999999992,
#   'changePercent': -0.0053}]

# %%
apple_df =pd.DataFrame(api_data)
apple_df.head()
# Out:
#     close      high     low     open symbol     volume                 id  \
# 0  148.56  148.7177  146.92  147.550   AAPL   71447416  HISTORICAL_PRICES
# 1  148.99  149.8300  147.70  148.270   AAPL   72434089  HISTORICAL_PRICES
# 2  146.77  149.2100  145.55  149.120   AAPL  104818578  HISTORICAL_PRICES
# 3  144.98  146.9700  142.54  144.810   AAPL  118931191  HISTORICAL_PRICES
# 4  145.64  146.5500  144.58  144.685   AAPL   56699475  HISTORICAL_PRICES
#
#     key subkey        date  ...    uLow    uVolume     fOpen    fClose  \
# 0  AAPL         2021-07-23  ...  146.92   71447416  147.3293  148.3378
# 1  AAPL         2021-07-26  ...  147.70   72434089  148.0482  148.7671
# 2  AAPL         2021-07-27  ...  145.55  104818578  148.8969  146.5504
# 3  AAPL         2021-07-28  ...  142.54  118931191  144.5934  144.7631
# 4  AAPL         2021-07-29  ...  144.58   56699475  144.4686  145.4221
#
#       fHigh      fLow    fVolume       label  change  changePercent
# 0  148.4952  146.7002   71447416  Jul 23, 21    0.00         0.0000
# 1  149.6059  147.4790   72434089  Jul 26, 21    0.43         0.0029
# 2  148.9868  145.3323  104818578  Jul 27, 21   -2.22        -0.0149
# 3  146.7501  142.3268  118931191  Jul 28, 21   -1.79        -0.0122
# 4  146.3308  144.3637   56699475  Jul 29, 21    0.66         0.0046
#
# [5 rows x 26 columns]

# %%
apple_df['date'] = pd.to_datetime(apple_df['date'], format="%Y-%m-%d")

# %%
apple_df['date']
# Out:
# 0    2021-07-23
# 1    2021-07-26
# 2    2021-07-27
# 3    2021-07-28
# 4    2021-07-29
#         ...
# 60   2021-10-18
# 61   2021-10-19
# 62   2021-10-20
# 63   2021-10-21
# 64   2021-10-22
# Name: date, Length: 65, dtype: datetime64[ns]

# %%
apple_df=apple_df.set_index("date")
apple_df
# Out:
#              close      high     low     open symbol     volume  \
# date
# 2021-07-23  148.56  148.7177  146.92  147.550   AAPL   71447416
# 2021-07-26  148.99  149.8300  147.70  148.270   AAPL   72434089
# 2021-07-27  146.77  149.2100  145.55  149.120   AAPL  104818578
# 2021-07-28  144.98  146.9700  142.54  144.810   AAPL  118931191
# 2021-07-29  145.64  146.5500  144.58  144.685   AAPL   56699475
# ...            ...       ...     ...      ...    ...        ...
# 2021-10-18  146.55  146.8400  143.16  143.445   AAPL   85589175
# 2021-10-19  148.76  149.1700  146.55  147.010   AAPL   76378894
# 2021-10-20  149.26  149.7539  148.12  148.700   AAPL   58418788
# 2021-10-21  149.48  149.6400  147.87  148.810   AAPL   61420990
# 2021-10-22  148.69  150.1800  148.64  149.690   AAPL   58883443
#
#                            id   key subkey        updated  ...    uLow  \
# date                                                       ...
# 2021-07-23  HISTORICAL_PRICES  AAPL         1628263045000  ...  146.92
# 2021-07-26  HISTORICAL_PRICES  AAPL         1628262969000  ...  147.70
# 2021-07-27  HISTORICAL_PRICES  AAPL         1628263045000  ...  145.55
# 2021-07-28  HISTORICAL_PRICES  AAPL         1628263067000  ...  142.54
# 2021-07-29  HISTORICAL_PRICES  AAPL         1628262969000  ...  144.58
# ...                       ...   ...    ...            ...  ...     ...
# 2021-10-18  HISTORICAL_PRICES  AAPL         1634605250000  ...  143.16
# 2021-10-19  HISTORICAL_PRICES  AAPL         1634692665000  ...  146.55
# 2021-10-20  HISTORICAL_PRICES  AAPL         1634778299000  ...  148.12
# 2021-10-21  HISTORICAL_PRICES  AAPL         1634864601000  ...  147.87
# 2021-10-22  HISTORICAL_PRICES  AAPL         1634951877000  ...  148.64
#
#               uVolume     fOpen    fClose     fHigh      fLow    fVolume  \
# date
# 2021-07-23   71447416  147.3293  148.3378  148.4952  146.7002   71447416
# 2021-07-26   72434089  148.0482  148.7671  149.6059  147.4790   72434089
# 2021-07-27  104818578  148.8969  146.5504  148.9868  145.3323  104818578
# 2021-07-28  118931191  144.5934  144.7631  146.7501  142.3268  118931191
# 2021-07-29   56699475  144.4686  145.4221  146.3308  144.3637   56699475
# ...               ...       ...       ...       ...       ...        ...
# 2021-10-18   85589175  143.4450  146.5500  146.8400  143.1600   85589175
# 2021-10-19   76378894  147.0100  148.7600  149.1700  146.5500   76378894
# 2021-10-20   58418788  148.7000  149.2600  149.7539  148.1200   58418788
# 2021-10-21   61420990  148.8100  149.4800  149.6400  147.8700   61420990
# 2021-10-22   58883443  149.6900  148.6900  150.1800  148.6400   58883443
#
#                  label  change  changePercent
# date
# 2021-07-23  Jul 23, 21    0.00         0.0000
# 2021-07-26  Jul 26, 21    0.43         0.0029
# 2021-07-27  Jul 27, 21   -2.22        -0.0149
# 2021-07-28  Jul 28, 21   -1.79        -0.0122
# 2021-07-29  Jul 29, 21    0.66         0.0046
# ...                ...     ...            ...
# 2021-10-18  Oct 18, 21    1.71         0.0118
# 2021-10-19  Oct 19, 21    2.21         0.0151
# 2021-10-20  Oct 20, 21    0.50         0.0034
# 2021-10-21  Oct 21, 21    0.22         0.0015
# 2021-10-22  Oct 22, 21   -0.79        -0.0053
#
# [65 rows x 25 columns]

# %%
apple_df['close'].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
apple_df[['open', 'close', 'high', 'low']].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
apple_df[['open', 'close', 'high', 'low']].plot(figsize=(12,4))
# Out:
# <AxesSubplot:xlabel='date'>

# %%
from nbresult import ChallengeResult

result = ChallengeResult('apple',
    index_name=apple_df.index.name,
    index_type=apple_df.index.dtype,
    columns=apple_df.columns
)
result.write()
print(result.check())
# Out:
# ============================= test session starts ==============================
# platform darwin -- Python 3.8.12, pytest-6.2.5, py-1.10.0, pluggy-1.0.0 -- /Users/shu/.pyenv/versions/lewagon/bin/python3
# cachedir: .pytest_cache
# rootdir: /Users/shu/Desktop/Lewagon/code/shiro101010101/data-challenges/02-Data-Toolkit/02-Data-Sourcing/01-Stock-Market-API
# plugins: dash-2.0.0, anyio-3.3.2
# collecting ... collected 3 items
#
# tests/test_apple.py::TestApple::test_apple_df_columns PASSED             [ 33%]
# tests/test_apple.py::TestApple::test_apple_df_index_is_timestamp PASSED  [ 66%]
# tests/test_apple.py::TestApple::test_apple_df_index_name_is_date PASSED  [100%]
#
# ============================== 3 passed in 1.60s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/apple.pickle
#
# git commit -m 'Completed apple step'
#
# git push origin master
